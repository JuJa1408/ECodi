# %%
import pandas as pd # enables manipulation of dataframes in Python
import numpy as np # enables manipulation of arrays in Python
import random # fetches random values
from urllib.request import urlretrieve # enables the downloading of files from the internet via URL
import gzip # module to enable I/O of gzipped files
import shutil # module to perform operations on files
from Bio import SeqIO # import the SeqIO Biopython module for working with sequence data
import matplotlib.pyplot as plt # import the matplotlib graphics module
import seaborn as sns # import the seaborn graphics module
import warnings # module to manage warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # prevent Python from warning of future feature deprecation

# %%
path_homo="Homo_sapiens.GRCh38.113_geneonly.gtf"

gtf_columns = [
    "seqname", "source", "feature", "start", "end", "score", "strand", "frame", "attributes"
]

# Read the GTF file
df_homo = pd.read_csv(path_homo, sep="\t", comment="#", names=gtf_columns, dtype={"seqname": str, "start": int, "end": int})


# Display the first few rows

df_homo
# Out:
#           seqname          source feature     start       end score strand  \
# 0               1  ensembl_havana    gene   3069168   3438621     .      +
# 1               1          havana    gene   5301928   5307394     .      -
# 2               1  ensembl_havana    gene   2403964   2413797     .      -
# 3               1          havana    gene   5492978   5494674     .      +
# 4               1          havana    gene  10054445  10054781     .      -
# ...           ...             ...     ...       ...       ...   ...    ...
# 78927  KI270717.1   havana_tagene    gene     15119     17798     .      -
# 78928  KI270717.1   havana_tagene    gene     24947     37269     .      +
# 78929  KI270720.1   havana_tagene    gene      3633     31375     .      -
# 78930  KI270718.1   havana_tagene    gene      6913     19848     .      -
# 78931  KI270755.1   havana_tagene    gene     26350     27723     .      +
#
#       frame                                         attributes
# 0         .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 1         .  gene_id "ENSG00000284616"; gene_version "1"; g...
# 2         .  gene_id "ENSG00000157911"; gene_version "11"; ...
# 3         .  gene_id "ENSG00000260972"; gene_version "1"; g...
# 4         .  gene_id "ENSG00000224340"; gene_version "1"; g...
# ...     ...                                                ...
# 78927     .  gene_id "ENSG00000307722"; gene_version "1"; g...
# 78928     .  gene_id "ENSG00000310401"; gene_version "1"; g...
# 78929     .  gene_id "ENSG00000302039"; gene_version "1"; g...
# 78930     .  gene_id "ENSG00000309831"; gene_version "1"; g...
# 78931     .  gene_id "ENSG00000309258"; gene_version "1"; g...
#
# [78932 rows x 9 columns]

# %%
pd.set_option('display.max_rows', None)
display(df_homo['seqname'].drop_duplicates())
pd.reset_option('display.max_rows')
# Out:
# 0                 1
# 7095              2
# 12780             3
# 16941             4
# 20521             5
# 24467             6
# 28697             7
# 32654             X
# 35610             8
# 38878             9
# 42068            11
# 46238            10
# 49507            12
# 53367            13
# 55367            14
# 58164            15
# 60983            16
# 64171            17
# 67951            18
# 69605            20
# 71575            19
# 75125             Y
# 75805            22
# 77553            21
# 78687            MT
# 78724    KI270728.1
# 78752    KI270727.1
# 78766    KI270442.1
# 78770    GL000225.1
# 78772    KI270743.1
# 78775    GL000008.2
# 78778    GL000009.2
# 78785    KI270722.1
# 78788    GL000194.1
# 78793    KI270742.1
# 78796    GL000205.2
# 78802    GL000195.1
# 78810    KI270733.1
# 78819    GL000224.1
# 78822    GL000219.1
# 78827    KI270719.1
# 78830    GL000216.2
# 78831    KI270712.1
# 78833    KI270706.1
# 78836    KI270744.1
# 78843    KI270734.1
# 78852    GL000213.1
# 78856    GL000220.1
# 78864    GL000218.1
# 78867    KI270749.1
# 78869    KI270741.1
# 78871    GL000221.1
# 78875    KI270731.1
# 78883    KI270751.1
# 78886    KI270750.1
# 78889    GL000214.1
# 78891    KI270721.1
# 78900    KI270748.1
# 78902    KI270746.1
# 78905    KI270753.1
# 78906    KI270726.1
# 78912    KI270711.1
# 78914    KI270745.1
# 78916    KI270714.1
# 78918    KI270713.1
# 78926    KI270710.1
# 78927    KI270717.1
# 78929    KI270720.1
# 78930    KI270718.1
# 78931    KI270755.1
# Name: seqname, dtype: object

# %%
raw_metadata = pd.read_csv("../Data/bacteria_counts_clean_highexpression.txt")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[95], line 2
#       1 with open("../Data/raw/Genome-patient-list.txt", "r", encoding="utf-8") as f:
# ----> 2     for line in f:
#       3         print(line.strip())  # Entfernt unsichtbare `\n`
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 51: invalid start byte

# %%
# %%R
# counts_data <- read.csv("../bacteria_counts_clean_highexpression.txt", row.names = 1)  # Ändere den Dateinamen entsprechend
# metadata <- read.csv("../metadata_clean.txt", row.names = 1)
# metadata$group <- gsub("[0-9]", "", metadata$library_name)
# metadata$run_accession <- rownames(metadata)
#
# rownames(counts_data) = counts_data$Geneid
# counts_data = counts_data[,-1]
# #summary(counts_data)
#
# par(mar=c(8,4,4,1)+0.1)
# barplot(colSums(counts_data), las=3, ylab= "Sum of counts")

# %%
# %%R
# logCountData = log2(1+counts_data)
# plot(logCountData$ERR950160, logCountData$ERR950159)

# %%
# %%R
# logCountData = log2(1+counts_data)
# plot(logCountData$ERR950168, logCountData$ERR950185)

# %%
# %%R
# colnames(metadata)
# Out:
# [1] "library_name" "group"

# %%
# %%R
# # Sicherstellen, dass Spaltennamen den run_accession entsprechen
# colnames(counts_data) <- gsub("^X", "", colnames(counts_data))  # Falls Spaltennamen "X..." haben
#
# # Summe der Counts pro Sample berechnen
# sum_counts <- colSums(counts_data)
#
# # Create dataframe with counts and groups
# df <- data.frame(run_accession = names(sum_counts), SumCounts = sum_counts)
# df <- merge(df, metadata, by = "run_accession", all.x = TRUE)
#
# # Define the correct order of groups
# group_order <- c("Hp", "Gast", "Atr", "EA", "Met")
#
# # Convert 'group' column to a factor with the desired order
# df$group <- factor(df$group, levels = group_order)
#
# # Compute mean and standard deviation per group
# group_means <- tapply(df$SumCounts, df$group, mean, na.rm = TRUE)
# group_sd <- tapply(df$SumCounts, df$group, sd, na.rm = TRUE)
#
# # Remove NA values (in case some groups are missing)
# group_means <- group_means[!is.na(group_means)]
# group_sd <- group_sd[!is.na(group_sd)]
# Out:
# R[write to console]: dev.new(): using pdf(file="Rplots1.pdf")

# %%
# %%R
# # Boxplot: Variability within groups
# boxplot(SumCounts ~ group, data = df,
#         col = c("lightblue", "lightgreen", "salmon", "orchid", "gold"),
#         main = "Distribution of Counts by Group",
#         xlab = "Group",
#         ylab = "Sum of Counts",
#         border = "black")

# %%
# %%R
# # Barplot with Error Bars: Mean + SD per group
# bar_x <- barplot(group_means,
#                  col = c("lightblue", "lightgreen", "salmon", "orchid", "gold"),
#                  ylim = c(0, max(group_means + group_sd) * 1.1),
#                  main = "Mean Counts with Variability",
#                  xlab = "Group",
#                  ylab = "Mean Sum of Counts",
#                  border = "black")
#
# # Add error bars (Standard Deviation)
# arrows(bar_x, group_means - group_sd, bar_x, group_means + group_sd,
#        angle = 90, code = 3, length = 0.1, col = "black", lwd = 2)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ✅ Daten laden
counts_data = pd.read_csv("../bacteria_counts_clean_highexpression.txt", index_col=0)

# Sicherstellen, dass Spalten numerisch sind
counts_data = counts_data.apply(pd.to_numeric, errors="coerce")

# ✅ Log-Transformation zur besseren Visualisierung (optional)
import numpy as np
counts_data_log = np.log1p(counts_data)  # log1p(x) = log(1 + x), vermeidet log(0)-Probleme

# ✅ Heatmap erstellen
plt.figure(figsize=(12, 8))
sns.heatmap(counts_data_log, cmap="viridis", linewidths=0.5, linecolor="gray", 
            xticklabels=True, yticklabels=False)  # Keine Gene-Beschriftung für Übersichtlichkeit

plt.title("Expression Heatmap (log-transformed)")
plt.xlabel("Samples")
plt.ylabel("Genes")
plt.show()

# %%
# ✅ Daten laden
counts_data = pd.read_csv("../bacteria_counts_clean_highexpression.txt", index_col=0)

# Sicherstellen, dass Spalten numerisch sind
counts_data = counts_data.apply(pd.to_numeric, errors="coerce")

# ✅ Log-Transformation zur besseren Visualisierung (optional)
import numpy as np
counts_data_log = np.log1p(counts_data)  # log1p(x) = log(1 + x), vermeidet log(0)-Probleme

# ✅ Heatmap erstellen
plt.figure(figsize=(12, 8))
sns.heatmap(counts_data_log, cmap="viridis", linewidths=0.5, linecolor="gray", 
            xticklabels=True, yticklabels=False)  # Keine Gene-Beschriftung für Übersichtlichkeit

plt.title("Expression Heatmap (log-transformed)")
plt.xlabel("Samples")
plt.ylabel("Genes")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns

counts_data_raw = pd.read_csv("../bacteria_counts_clean_highexpression.txt", index_col=0)
metadata = pd.read_csv("../metadata_clean.txt", index_col=0)

counts_data = counts_data_raw.loc[:, counts_data_raw.sum() != 0]

counts_data = counts_data.apply(pd.to_numeric, errors="coerce")

counts_data_log = np.log1p(counts_data)  # log1p(x) = log(1 + x), vermeidet log(0)-Probleme

scaler = StandardScaler()
counts_scaled = scaler.fit_transform(counts_data_log.T)  # Transponieren, damit Proben Zeilen sind

pca = PCA(n_components=2)  # Wir reduzieren auf 2 Hauptkomponenten
pca_results = pca.fit_transform(counts_scaled)

pca_df = pd.DataFrame(pca_results, columns=["PC1", "PC2"], index=counts_data.columns)

metadata["group"] = metadata["library_name"].str.replace(r"\d+", "", regex=True)  # Extrahiert Gruppenbuchstaben
pca_df["group"] = metadata.loc[pca_df.index, "group"]

plt.figure(figsize=(10, 7))
sns.scatterplot(x="PC1", y="PC2", hue="group", data=pca_df, palette="Set2", s=100, alpha=0.8)
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)")
plt.title("PCA of Counts Data")
plt.legend(title="Group")
plt.axhline(0, linestyle="dashed", color="gray", alpha=0.5)
plt.axvline(0, linestyle="dashed", color="gray", alpha=0.5)
plt.show()
plt.savefig("PCAstages.png")

# %%
counts_data.head()
# Out:
#          ERR950158  ERR950159  ERR950160  ERR950161  ERR950162  ERR950163  \
# Geneid
# HP_0573          4          5          8          7          0          2
# HP_0020         12          6          5         10         14          0
# HP_1325         10          9         28         12         16          3
# HP_0038          2          0          0          0          0          0
# HP_0493          2          0          0          2          0          0
#
#          ERR950164  ERR950165  ERR950166  ERR950167  ...  ERR950178  \
# Geneid                                               ...
# HP_0573         17          1         13          4  ...          0
# HP_0020         23          2          2         19  ...          0
# HP_1325         18          6         26         85  ...          0
# HP_0038          2          0          0          2  ...          0
# HP_0493         10          8          6          6  ...          0
#
#          ERR950179  ERR950180  ERR950181  ERR950182  ERR950183  ERR950184  \
# Geneid
# HP_0573          0         18          0          2          0          5
# HP_0020          0         18          2          5          6          5
# HP_1325          0         65          2         14          6         12
# HP_0038          0         17          2          0          0          0
# HP_0493          0         16          0          2          0          4
#
#          ERR950185  ERR950186  ERR950187
# Geneid
# HP_0573          2          0          0
# HP_0020          6          0          0
# HP_1325          4          0          0
# HP_0038          0          0          0
# HP_0493          4          0          0
#
# [5 rows x 30 columns]

# %%
counts_melted = counts_df.melt(id_vars=["Geneid"], var_name="run_accession", value_name="counts")
df = counts_melted.merge(metadata, on="run_accession")
df = df[df["Geneid"].str.startswith("H")]
df["stage"] = df["library_name"].str.extract(r'([A-Za-z]+)')
df
# Out:
#           Geneid run_accession  counts library_name stage
# 0        HP_0573     ERR950158       4         Atr1   Atr
# 1        HP_0020     ERR950158      12         Atr1   Atr
# 2        HP_1325     ERR950158      10         Atr1   Atr
# 3        HP_0038     ERR950158       2         Atr1   Atr
# 4        HP_0765     ERR950158       0         Atr1   Atr
# ...          ...           ...     ...          ...   ...
# 2337293   HP_t07     ERR950187       0         Hp-4    Hp
# 2337294   HP_t08     ERR950187       0         Hp-4    Hp
# 2337295   HP_r07     ERR950187      18         Hp-4    Hp
# 2337296   HP_t12     ERR950187       0         Hp-4    Hp
# 2337297   HP_t06     ERR950187       0         Hp-4    Hp
#
# [48270 rows x 5 columns]

# %%
gene_variances = df.groupby(["Geneid", "stage"])["counts"].var().reset_index()
gene_variances
# Out:
#        Geneid stage     counts
# 0     HP_0001   Atr   6.111111
# 1     HP_0001    EA   2.400000
# 2     HP_0001  Gast  15.600000
# 3     HP_0001    Hp   0.000000
# 4     HP_0001   Met   9.000000
# ...       ...   ...        ...
# 8040   HP_t36   Atr   1.250000
# 8041   HP_t36    EA   0.666667
# 8042   HP_t36  Gast   0.000000
# 8043   HP_t36    Hp   0.000000
# 8044   HP_t36   Met   0.000000
#
# [8045 rows x 3 columns]

# %%
# Pivot für Heatmap
pivot = gene_variances.pivot(index="Geneid", columns="stage", values="counts")

stage_order = ["Hp", "Gast", "Atr", "EA", "Met"]  # Wunsch-Reihenfolge
pivot = pivot.reindex(columns=stage_order)  # Sortiere die Spalten nach der Reihenfolge

# 5. Wähle die 50 Gene mit der höchsten Varianz
top_genes = pivot.var(axis=1).nlargest(50).index  # Hier kannst du die Anzahl erhöhen
pivot_filtered = pivot.loc[top_genes].fillna(0)  # Fehlende Werte mit 0 füllen

# 6. Dynamische Größe basierend auf Anzahl der Gene
gene_count = len(pivot_filtered)
fig_height = max(6, gene_count * 0.3)

# 7. Zeichne die Heatmap mit festgelegter Kategorie-Reihenfolge
plt.figure(figsize=(12, fig_height))
sns.heatmap(pivot_filtered, cmap="coolwarm", annot=True, linewidths=0.5, fmt=".2f")

plt.title(f"Top {gene_count} genes with highest variance between groups")
plt.xlabel("Kategorie")
plt.ylabel("Geneid")
plt.xticks(rotation=45)  # Leichtere Lesbarkeit der Labels
plt.yticks(rotation=0)
plt.show()

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages("IRkernel")
# IRkernel::installspec(user = FALSE)  # Installiert den Kernel global für Jupyter
# Out:
# R[write to console]: Warning in install.packages("IRkernel") :
# R[write to console]:
#
# R[write to console]:  'lib = "/opt/conda/lib/R/library"' is not writable
# Would you like to use a personal library instead? (yes/No/cancel)  cancle
# R[write to console]: Error in askYesNo(gettext("Would you like to use a personal library instead?"),  :
#   Unrecognized response "cancle"
# Error in askYesNo(gettext("Would you like to use a personal library instead?"),  :
#   Unrecognized response "cancle"
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:385, in RMagics.eval(self, code)
#     383 try:
#     384     # Need the newline in case the last line in code is a comment.
# --> 385     value, visible = ro.r("withVisible({%s\n})" % code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in askYesNo(gettext("Would you like to use a personal library instead?"),  :
#   Unrecognized response "cancle"
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', 'install.packages("IRkernel")\nIRkernel::installspec(user = FALSE)  # Installiert den Kernel global für Jupyter\n')
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2539, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2537 with self.builtin_trap:
#    2538     args = (magic_arg_s, cell)
# -> 2539     result = fn(*args, **kwargs)
#    2541 # The code below prevents the output from being displayed
#    2542 # when using magics with decorator @output_can_be_silenced
#    2543 # when the last Python token in the expression is a ';'.
#    2544 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:943, in RMagics.R(self, line, cell, local_ns)
#     941     if not e.stdout.endswith(e.err):
#     942         print(e.err)
# --> 943     raise e
#     944 finally:
#     945     if self.device in DEVICES_STATIC:
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:923, in RMagics.R(self, line, cell, local_ns)
#     921         return_output = False
#     922 else:
# --> 923     text_result, result, visible = self.eval(code)
#     924     text_output += text_result
#     925     if visible:
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:389, in RMagics.eval(self, code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#     388     warning_or_other_msg = self.flush()
# --> 389     raise RInterpreterError(code, str(exception),
#     390                             warning_or_other_msg)
#     391 text_output = self.flush()
#     392 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line 'install.packages("IRkernel")\nIRkernel::installspec(user = FALSE)  # Installiert den Kernel global für Jupyter\n'.
# R error message: 'Error in askYesNo(gettext("Would you like to use a personal library instead?"),  : \n  Unrecognized response "cancle"'

# %%
# %%R
# # Lade DESeq2 und andere notwendige Pakete
# library(DESeq2)
#
# # Beispiel-Daten einladen
# # Angenommen, counts_df und metadata_df sind in CSV-Dateien gespeichert
# counts_data <- read.csv("counts_clean.txt", row.names = 1)  # Ändere den Dateinamen entsprechend
# metadata <- read.csv("metadata_clean.txt", row.names = 1)
#
# # DESeqDataSet erstellen
# dds <- DESeqDataSetFromMatrix(countData = counts_data,
#                               colData = metadata,
#                               design = ~ library_name)  # Passen Sie das Design entsprechend an
#
# # Führe die DESeq2-Analyse aus
# dds <- DESeq(dds)
#
# # Erhalte die Ergebnisse
# res <- results(dds)
#
# # Ergebnisse anzeigen
# summary(res)
# Out:
# R[write to console]: Error in library(DESeq2) : there is no package called 'DESeq2'
# Error in library(DESeq2) : there is no package called 'DESeq2'
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:385, in RMagics.eval(self, code)
#     383 try:
#     384     # Need the newline in case the last line in code is a comment.
# --> 385     value, visible = ro.r("withVisible({%s\n})" % code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in library(DESeq2) : there is no package called 'DESeq2'
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', '# Lade DESeq2 und andere notwendige Pakete\nlibrary(DESeq2)\n\n# Beispiel-Daten einladen\n# Angenommen, counts_df und metadata_df sind in CSV-Dateien gespeichert\ncounts_data <- read.csv("counts_clean.txt", row.names = 1)  # Ändere den Dateinamen entsprechend\nmetadata <- read.csv("metadata_clean.txt", row.names = 1)\n\n# DESeqDataSet erstellen\ndds <- DESeqDataSetFromMatrix(countData = counts_data,\n                              colData = metadata,\n                              design = ~ library_name)  # Passen Sie das Design entsprechend an\n\n# Führe die DESeq2-Analyse aus\ndds <- DESeq(dds)\n\n# Erhalte die Ergebnisse\nres <- results(dds)\n\n# Ergebnisse anzeigen\nsummary(res)\n')
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2539, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2537 with self.builtin_trap:
#    2538     args = (magic_arg_s, cell)
# -> 2539     result = fn(*args, **kwargs)
#    2541 # The code below prevents the output from being displayed
#    2542 # when using magics with decorator @output_can_be_silenced
#    2543 # when the last Python token in the expression is a ';'.
#    2544 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:943, in RMagics.R(self, line, cell, local_ns)
#     941     if not e.stdout.endswith(e.err):
#     942         print(e.err)
# --> 943     raise e
#     944 finally:
#     945     if self.device in DEVICES_STATIC:
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:923, in RMagics.R(self, line, cell, local_ns)
#     921         return_output = False
#     922 else:
# --> 923     text_result, result, visible = self.eval(code)
#     924     text_output += text_result
#     925     if visible:
#
# File /opt/conda/lib/python3.11/site-packages/rpy2/ipython/rmagic.py:389, in RMagics.eval(self, code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#     388     warning_or_other_msg = self.flush()
# --> 389     raise RInterpreterError(code, str(exception),
#     390                             warning_or_other_msg)
#     391 text_output = self.flush()
#     392 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line '# Lade DESeq2 und andere notwendige Pakete\nlibrary(DESeq2)\n\n# Beispiel-Daten einladen\n# Angenommen, counts_df und metadata_df sind in CSV-Dateien gespeichert\ncounts_data <- read.csv("counts_clean.txt", row.names = 1)  # Ändere den Dateinamen entsprechend\nmetadata <- read.csv("metadata_clean.txt", row.names = 1)\n\n# DESeqDataSet erstellen\ndds <- DESeqDataSetFromMatrix(countData = counts_data,\n                              colData = metadata,\n                              design = ~ library_name)  # Passen Sie das Design entsprechend an\n\n# Führe die DESeq2-Analyse aus\ndds <- DESeq(dds)\n\n# Erhalte die Ergebnisse\nres <- results(dds)\n\n# Ergebnisse anzeigen\nsummary(res)\n'.
# R error message: "Error in library(DESeq2) : there is no package called 'DESeq2'"
